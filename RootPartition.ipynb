# %%
import uproot

# %%
file = uproot.open('/Users/xweichu/Desktop/nano_dy.root')

# %%
file
# Out:
# <ROOTDirectory b'nano_tree.root' at 0x000118997550>

# %%
file.keys()
# Out:
# [b'Runs;1', b'Events;1']

# %%
file.values()
# Out:
# [<TTree b'Runs' at 0x000118962710>, <TTree b'Events' at 0x000118962470>]

# %%
file['Events']
# Out:
# <TTree b'Events' at 0x000117e5deb8>

# %%
file['Events'].keys()
# Out:
# [b'run',
#  b'luminosityBlock',
#  b'event',
#  b'CaloMET_phi',
#  b'CaloMET_pt',
#  b'CaloMET_sumEt',
#  b'nElectron',
#  b'Electron_deltaEtaSC',
#  b'Electron_dr03EcalRecHitSumEt',
#  b'Electron_dr03HcalDepth1TowerSumEt',
#  b'Electron_dr03TkSumPt',
#  b'Electron_dxy',
#  b'Electron_dxyErr',
#  b'Electron_dz',
#  b'Electron_dzErr',
#  b'Electron_eCorr',
#  b'Electron_eInvMinusPInv',
#  b'Electron_energyErr',
#  b'Electron_eta',
#  b'Electron_hoe',
#  b'Electron_ip3d',
#  b'Electron_mass',
#  b'Electron_miniPFRelIso_all',
#  b'Electron_miniPFRelIso_chg',
#  b'Electron_mvaFall17Iso',
#  b'Electron_mvaFall17noIso',
#  b'Electron_pfRelIso03_all',
#  b'Electron_pfRelIso03_chg',
#  b'Electron_phi',
#  b'Electron_pt',
#  b'Electron_r9',
#  b'Electron_sieie',
#  b'Electron_sip3d',
#  b'Electron_mvaTTH',
#  b'Electron_charge',
#  b'Electron_cutBased',
#  b'Electron_jetIdx',
#  b'Electron_pdgId',
#  b'Electron_photonIdx',
#  b'Electron_tightCharge',
#  b'Electron_vidNestedWPBitmap',
# ...

# %%
file['Events']['event']
# Out:
# <TBranch b'event' at 0x000117f34b38>

# %%
file['Events']['event']
# Out:
# <TBranch b'event' at 0x000117e5ddd8>

# %%
file['Events'].show()
# Out:
# run                        (no streamer)              asdtype('>u4')
# luminosityBlock            (no streamer)              asdtype('>u4')
# event                      (no streamer)              asdtype('>u8')
# CaloMET_phi                (no streamer)              asdtype('>f4')
# CaloMET_pt                 (no streamer)              asdtype('>f4')
# CaloMET_sumEt              (no streamer)              asdtype('>f4')
# nElectron                  (no streamer)              asdtype('>u4')
# Electron_deltaEtaSC        (no streamer)              asjagged(asdtype('>f4'))
# Electron_dr03EcalRecHitSumEt
#                            (no streamer)              asjagged(asdtype('>f4'))
# Electron_dr03HcalDepth1TowerSumEt
#                            (no streamer)              asjagged(asdtype('>f4'))
# Electron_dr03TkSumPt       (no streamer)              asjagged(asdtype('>f4'))
# Electron_dxy               (no streamer)              asjagged(asdtype('>f4'))
# ...

# %%
file['Events'].name
# Out:
# b'Events'

# %%
file['Events'].title
# Out:
# b'Events'

# %%
file['Events'].numentries
# Out:
# 10

# %%
file['Events']['Electron_dxyErr'].interpretation
# Out:
# asjagged(asdtype('>f4'))

# %%
file['Events'].keys()
# Out:
# [b'run',
#  b'luminosityBlock',
#  b'event',
#  b'CaloMET_phi',
#  b'CaloMET_pt',
#  b'CaloMET_sumEt',
#  b'nElectron',
#  b'Electron_deltaEtaSC',
#  b'Electron_dr03EcalRecHitSumEt',
#  b'Electron_dr03HcalDepth1TowerSumEt',
#  b'Electron_dr03TkSumPt',
#  b'Electron_dxy',
#  b'Electron_dxyErr',
#  b'Electron_dz',
#  b'Electron_dzErr',
#  b'Electron_eCorr',
#  b'Electron_eInvMinusPInv',
#  b'Electron_energyErr',
#  b'Electron_eta',
#  b'Electron_hoe',
#  b'Electron_ip3d',
#  b'Electron_mass',
#  b'Electron_miniPFRelIso_all',
#  b'Electron_miniPFRelIso_chg',
#  b'Electron_mvaFall17Iso',
#  b'Electron_mvaFall17noIso',
#  b'Electron_pfRelIso03_all',
#  b'Electron_pfRelIso03_chg',
#  b'Electron_phi',
#  b'Electron_pt',
#  b'Electron_r9',
#  b'Electron_sieie',
#  b'Electron_sip3d',
#  b'Electron_mvaTTH',
#  b'Electron_charge',
#  b'Electron_cutBased',
#  b'Electron_jetIdx',
#  b'Electron_pdgId',
#  b'Electron_photonIdx',
#  b'Electron_tightCharge',
#  b'Electron_vidNestedWPBitmap',
# ...

# %%
jd_arr = file['Events']['GenJetAK8_mass'].array()
dir(jd_arr)
jd_arr.shape
# Out:
# (10,)

# %%
file['Events']['GenPart_phi']
# Out:
# <TBranch b'GenPart_phi' at 0x000110722b70>

# %%
import numpy
jd_arr = file['Events'].array('GenPart_phi')
# print(jd_arr[0])
# for item in jd_arr:
#     print(type(item))
#     print(item)
import pyarrow as pa
import pyarrow.parquet as pq


data = pa.array(jd_arr)
print(data)
# table = pa.Table.from_arrays(jd_arr)

# print(table)
# dir(data)
# pq.write_table(table, 'GenPart_phi')
# Out:
# [
#   [
#     0,
#     0,
#     2.52344,
#     -0.619141,
#     2.625,
#     2.625,
#     2.625,
#     2.61719,
#     2.72656,
#     -0.292969,
#     ...
#     -0.30957,
#     -0.259766,
#     2.74219,
#     2.72656,
#     2.64844,
#     -0.685547,
#     -0.0861816,
#     -0.201172,
#     -0.313477,
#     -0.289062
#   ],
#   [
#     0,
#     0,
#     0,
#     -1.27344,
#     -1.71875,
#     1.76562,
#     -1.37891,
#     -0.996094,
#     0.220703,
#     1.26562,
#     -2.23438,
#     2.55469,
#     2.99219,
#     -2.80469,
#     0.286133,
#     -2.24219,
#     -2.17969,
#     -2.4375,
#     0.230957,
#     0.166992
#   ],
#   [
#     0,
#     0,
#     -0.244629,
#     2.89844,
#     -0.107666,
#     -0.140137,
#     -0.152344,
#     -0.14209,
#     -0.158203,
#     -0.157715,
#     ...
#     -2.46094,
#     -0.0556641,
#     2,
#     -3.07812,
#     -3.08594,
#     2.60156,
#     1.81641,
#     2.03906,
#     2.57031,
#     2.39844
#   ],
#   [
#     0,
#     0,
#     0,
# ...

# %%
file['Events']['CaloMET_sumEt'].array()
# Out:
# array([ 889.5 ,  979.  , 1302.  ,  844.  ,  837.5 , 1463.  ,  734.5 ,
#         487.25,  576.  , 1026.  ], dtype=float32)

# %%
file['Events'].lazyarrays()
# Out:
# {b'run': <LazyArray 'run' at 00011aaaa6a0>,
#  b'luminosityBlock': <LazyArray 'luminosityBlock' at 00011aaaa6d8>,
#  b'event': <LazyArray 'event' at 00011aaaa710>,
#  b'CaloMET_phi': <LazyArray 'CaloMET_phi' at 00011aaaa748>,
#  b'CaloMET_pt': <LazyArray 'CaloMET_pt' at 00011aaaa780>,
#  b'CaloMET_sumEt': <LazyArray 'CaloMET_sumEt' at 00011aaaa7b8>,
#  b'nElectron': <LazyArray 'nElectron' at 00011aaaa7f0>,
#  b'Electron_deltaEtaSC': <LazyArray 'Electron_deltaEtaSC' at 00011aaaa828>,
#  b'Electron_dr03EcalRecHitSumEt': <LazyArray 'Electron_dr03EcalRecHitSumEt' at 00011aaaa860>,
#  b'Electron_dr03HcalDepth1TowerSumEt': <LazyArray 'Electron_dr03HcalDepth1TowerSumEt' at 00011aaaa898>,
#  b'Electron_dr03TkSumPt': <LazyArray 'Electron_dr03TkSumPt' at 00011aaaa8d0>,
#  b'Electron_dxy': <LazyArray 'Electron_dxy' at 00011aaaa908>,
#  b'Electron_dxyErr': <LazyArray 'Electron_dxyErr' at 00011aaaa940>,
#  b'Electron_dz': <LazyArray 'Electron_dz' at 00011aaaa978>,
# ...

# %%
dask_arr = uproot.daskarray('/Users/xweichu/Desktop/nano_dy.root','Events','Photon_isScEtaEB')

# %%
dask_arr
# Out:
# dask.array<array, shape=(10,), dtype=object, chunksize=(10,)>

# %%
arrs = file['Events'].arrays('Electron*')

# %%
arrs.get('Electron_deltaEtaSC')
